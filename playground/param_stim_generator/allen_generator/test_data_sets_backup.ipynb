# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
import os

# %%
stims_path = './stims/'
target_path = './target_volts/'

# %%
model_number = '485835016'

# %%
stims_file_str = stims_path+'allen_data_stims_{}.hdf5'
target_file_str = target_path+'allen_data_target_volts_{}.hdf5'
stims = h5py.File(stims_file_str.format(model_number), 'r')
target_volts = h5py.File(target_file_str.format(model_number), 'r')

# %%
sweep_keys = [e.decode('ascii') for e in stims['sweep_keys']]

# %%
# for key in sweep_keys:
#     print("Stim sweep number", key)
#     plt.plot(stims[key])
#     plt.show()

# %%
# xander
def get_target_volts(model_number,target_path):
    target_file_str = target_path+'allen_data_target_volts_{}.hdf5'
    target_volts = h5py.File(target_file_str.format(model_number), 'r')
    return target_volts

def get_stims(stims_path, model_number):
    stims_file_str = stims_path+'allen_data_stims_{}.hdf5'
    stims = h5py.File(stims_file_str.format(model_number), 'r')
    return stims

# %%
sweep_filter_1 = [str(e) for e in range(79, 100)]
sweep_filter_2 = ['101', '102', '103']

# %%
for key in sweep_keys:
    if not key in sweep_filter_1+sweep_filter_2:
        print("Stim sweep number", key)
        print("Max val:", np.max(stims[key]))
        print("Min val:", np.min(stims[key]))
        plt.plot(stims[key])
        plt.show()
# Out:
# Stim sweep number 6
# Max val: 0.18824999892252947
# Min val: 0.0
# Stim sweep number 7
# Max val: 0.1000000013351432
# Min val: 0.0
# Stim sweep number 8
# Max val: 0.2000000026702864
# Min val: 0.0
# Stim sweep number 9
# Max val: 0.2999999970665357
# Min val: 0.0
# Stim sweep number 10
# Max val: 0.4000000053405728
# Min val: 0.0
# Stim sweep number 11
# Max val: 0.49999998585903427
# Min val: 0.0
# Stim sweep number 12
# Max val: 0.5999999941330714
# Min val: 0.0
# Stim sweep number 13
# Max val: 0.7000000024071085
# Min val: 0.0
# Stim sweep number 14
# Max val: 0.8000000106811456
# Min val: 0.0
# Stim sweep number 15
# Max val: 0.9000000189551827
# Min val: 0.0
# Stim sweep number 16
# Max val: 0.9999999717180685
# Min val: 0.0
# Stim sweep number 17
# Max val: 1.0999999799921056
# Min val: 0.0
# Stim sweep number 18
# Max val: 1.1999999882661427
# Min val: 0.0
# Stim sweep number 19
# Max val: 1.1499999841291242
# Min val: 0.0
# Stim sweep number 21
# Max val: 1.159999984956528
# Min val: 0.0
# Stim sweep number 23
# Max val: 1.1699999857839316
# Min val: 0.0
# Stim sweep number 26
# Max val: 0.0
# Min val: -0.1100000021625469
# Stim sweep number 27
# Max val: 0.0
# Min val: -0.09000000050773949
# Stim sweep number 28
# Max val: 0.0
# Min val: -0.06999999885293207
# Stim sweep number 29
# Max val: 0.0
# Min val: -0.0500000006675716
# Stim sweep number 30
# Max val: 0.0
# Min val: -0.03000000248221113
# Stim sweep number 32
# Max val: 0.009999999960041972
# Min val: 0.0
# Stim sweep number 33
# Max val: 0.03000000248221113
# Min val: 0.0
# Stim sweep number 34
# Max val: 0.0500000006675716
# Min val: 0.0
# Stim sweep number 35
# Max val: 0.06999999885293207
# Min val: 0.0
# Stim sweep number 36
# Max val: 0.09000000050773949
# Min val: 0.0
# Stim sweep number 37
# Max val: 0.1100000021625469
# Min val: 0.0
# Stim sweep number 38
# Max val: 0.12999999687846042
# Min val: 0.0
# Stim sweep number 39
# Max val: 0.14999999853326784
# Min val: 0.0
# Stim sweep number 41
# Max val: 0.19000000184288268
# Min val: 0.0
# Stim sweep number 42
# Max val: 0.2099999896199023
# Min val: 0.0
# Stim sweep number 43
# Max val: 0.23000000515249752
# Min val: 0.0
# Stim sweep number 44
# Max val: 0.24999999292951713
# Min val: 0.0
# Stim sweep number 45
# Max val: 0.26999999458432455
# Min val: 0.0
# Stim sweep number 46
# Max val: 0.289999996239132
# Min val: 0.0
# Stim sweep number 47
# Max val: 0.3099999978939394
# Min val: 0.0
# Stim sweep number 48
# Max val: 0.15999999936067155
# Min val: 0.0
# Stim sweep number 52
# Max val: 0.17000000018807526
# Min val: 0.0
# Stim sweep number 55_1
# Max val: 0.13137499421667087
# Min val: 0.0
# Stim sweep number 55_2
# Max val: 0.26274998843334174
# Min val: 0.0
# Stim sweep number 55_3
# Max val: 0.39399999929301543
# Min val: 0.0
# Stim sweep number 60_1
# Max val: 0.13362499995395183
# Min val: 0.0
# Stim sweep number 60_2
# Max val: 0.26724999990790366
# Min val: 0.0
# Stim sweep number 60_3
# Max val: 0.4007500165048583
# Min val: 0.0
# Stim sweep number 63
# Max val: 0.2000000026702864
# Min val: -0.2000000026702864
# Stim sweep number 65
# Max val: 0.18000000101547897
# Min val: 0.0
# Stim sweep number 68
# Max val: 0.18000000101547897
# Min val: 0.0
# Stim sweep number 71
# Max val: 0.2200000043250938
# Min val: 0.0
# Stim sweep number 75
# Max val: 0.25999999375692084
# Min val: 0.0

# %%
# This is the original cell
stims_to_match = h5py.File('./filtered_dataset/cell_488683425/allen_data_stims_10000.hdf5', 'r')
sweep_index_to_match = ['4',\
                        '23',\
                        '22',\
                        '48_3',\
                        '53_3',\
                        '51_1',\
                        '58',\
                        '48_1',\
                        '66',\
                        '48_2',\
                        '44',\
                        '16',\
                        '38',\
                        '28',\
                        '13',\
                        '18',\
                        '15',\
                        '14']

# %%
matched_sweep_numbers = []
for stim_num in sweep_index_to_match:
    match_stim = stims_to_match[stim_num]
    print("Original sweep number:", stim_num)
    plt.plot(match_stim, color='red')
    plt.show()
    for key in sweep_keys:
        if not key in sweep_filter_1+sweep_filter_2:
            curr_stim = stims[key]
            diff_max = abs(np.max(match_stim)-np.max(curr_stim))
            diff_min = abs(np.min(match_stim)-np.min(curr_stim))
            if diff_max < 0.0005 and diff_min < 0.0005:
                print("Matched sweep number:", key)
                matched_sweep_numbers.append(key)
                plt.plot(curr_stim)
                plt.show()
# Out:
# Original sweep number: 4
# Matched sweep number: 6
# Original sweep number: 23
# Matched sweep number: 27
# Original sweep number: 22
# Matched sweep number: 26
# Original sweep number: 48_3
# Matched sweep number: 60_3
# Original sweep number: 53_3
# Matched sweep number: 55_3
# Original sweep number: 51_1
# Matched sweep number: 55_1
# Original sweep number: 58
# Matched sweep number: 52
# Original sweep number: 48_1
# Matched sweep number: 60_1
# Original sweep number: 66
# Matched sweep number: 44
# Original sweep number: 48_2
# Matched sweep number: 60_2
# Original sweep number: 44
# Matched sweep number: 52
# Original sweep number: 16
# Original sweep number: 38
# Matched sweep number: 42
# Original sweep number: 28
# Matched sweep number: 32
# Original sweep number: 13
# Matched sweep number: 13
# Original sweep number: 18
# Original sweep number: 15
# Original sweep number: 14

# %%
matched_sweep_numbers
# Out:
# ['6',
#  '27',
#  '26',
#  '60_3',
#  '55_3',
#  '55_1',
#  '52',
#  '60_1',
#  '44',
#  '60_2',
#  '52',
#  '42',
#  '32',
#  '13']

# %%
def sample(input_vec, target_len, curr_dt):
    vec_len = len(input_vec)
    scale_factor = int(vec_len/target_len)
    sampled_vec = []
    for i in range(0, vec_len, scale_factor):
        window = input_vec[i:i+scale_factor]
        sampled_vec.append(np.max(window))
    return sampled_vec

# %%
temp = target_volts['6'][:]
plt.plot(temp)
plt.show()
temp_sampled = sample(temp, 10000, target_volts['6_dt'][0])
plt.plot(temp_sampled, color='red')
plt.show()

# %%
stims_to_match.keys()
# Out:
# <KeysViewHDF5 ['12', '12_dt', '13', '13_dt', '14', '14_dt', '15', '15_dt', '16', '16_dt', '18', '18_dt', '22', '22_dt', '23', '23_dt', '28', '28_dt', '30', '30_dt', '31', '31_dt', '34', '34_dt', '35', '35_dt', '38', '38_dt', '4', '44', '44_dt', '48_1', '48_1_dt', '48_2', '48_2_dt', '48_3', '48_3_dt', '4_dt', '51_1', '51_1_dt', '51_2', '51_2_dt', '53_3', '53_3_dt', '56', '56_dt', '58', '58_dt', '65', '65_dt', '66', '66_dt', '8', '8_dt', '9', '9_dt', 'sweep_keys', 'sweep_numbers']>

# %%
stims_to_match['12_dt'][0]
# Out:
# 0.034999999999999996

# %%
stims_to_match['38_dt'][0]
# Out:
# 0.155
